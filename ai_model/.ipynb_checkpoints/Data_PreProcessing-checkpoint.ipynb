# %% [markdown]
# <h1 style="color:blue">Initial Finetuning of GPT-3 for Dreami </h1>
# On dreami.day, users will be able to get dream-interpretations generated by GPT-3 through an API to Opean-AI. Models can be fine-tuned to specialize in specific tasks. We have to provide pairs of dreams and dream-interpretations. The model then learns to generate dream-interpretations from dream input. We scraped two facebook groups to get intitial data.
# <h2>Data Preprocessing </h2>Scraping Facebook groups provides us with datasets where we have to filter out dream-texts in the posts and dream-interpretations in the comments. Let's import the first dataset into pandas.

# %%
import pandas as pd
import numpy as np

# %%
dreams_raw = pd.read_csv('Data/FB_scraped_Dream Symbols and Interpretation.csv')
dreams_raw.shape
# Out:
# (1605, 22)

# %%
dreams_raw.head()
# Out:
#            page_id           post_id  \
# 0  546590529195943  1221949978326658
# 1  546590529195943  1221949978326658
# 2  546590529195943  1221949978326658
# 3  546590529195943  1221949978326658
# 4  546590529195943  1221949978326658
#
#                                             post_url    user_id  \
# 0  https://m.facebook.com/groups/546590529195943/...  780839497
# 1  https://m.facebook.com/groups/546590529195943/...  780839497
# 2  https://m.facebook.com/groups/546590529195943/...  780839497
# 3  https://m.facebook.com/groups/546590529195943/...  780839497
# 4  https://m.facebook.com/groups/546590529195943/...  780839497
#
#        user_name                                          post_text  \
# 0  Timothy Kippo  Hello and welcome to the group!\r\n\r\nI hope ...
# 1  Timothy Kippo  Hello and welcome to the group!\r\n\r\nI hope ...
# 2  Timothy Kippo  Hello and welcome to the group!\r\n\r\nI hope ...
# 3  Timothy Kippo  Hello and welcome to the group!\r\n\r\nI hope ...
# 4  Timothy Kippo  Hello and welcome to the group!\r\n\r\nI hope ...
#
#              post_time  likes  comments  shares  ...  commenter_id  \
# 0  2021-08-14 06:44:34   76.0        25       0  ...  1.000005e+14
# 1  2021-08-14 06:44:34   76.0        25       0  ...  7.828891e+08
# 2  2021-08-14 06:44:34   76.0        25       0  ...  1.139412e+09
# 3  2021-08-14 06:44:34   76.0        25       0  ...  1.000010e+14
# 4  2021-08-14 06:44:34   76.0        25       0  ...  1.000010e+14
#
#     commenter_name                                       comment_text  \
# 0    Tonya Perkins  Thanks for accepting my request. I have many d...
# 1  Emilia Toivonen                        thanks for letting me join!
# 2      Debbie Ward                 Thank you for allowing me to join.
# 3      Elisah Meis  I personally would prefer is members would mak...
# 4      Elisah Meis  I personally would prefer is members would mak...
#
#           comment_time      reply_id                              reply_url  \
# 0  2021-11-08 14:40:17           NaN                                    NaN
# 1  2021-10-08 14:40:18           NaN                                    NaN
# 2  2021-10-08 14:40:18           NaN                                    NaN
# 3  2021-09-08 14:40:19  1.235685e+15  https://facebook.com/1235685116953144
# 4  2021-09-08 14:40:19  1.235686e+15  https://facebook.com/1235686206953035
#
#      replier_id replier_name  \
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3  1.000010e+14    Terry Dey
# 4  1.000010e+14  Elisah Meis
#
#                                           reply_text           reply_time
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3  Elisah Meis I agree but we've noticed many of ...  2021-09-08 14:40:34
# 4  Thats true... however a bit more info would be...  2021-09-08 14:40:34
#
# [5 rows x 22 columns]

# %%
dreams_raw.columns
# Out:
# Index(['page_id', 'post_id', 'post_url', 'user_id', 'user_name', 'post_text',
#        'post_time', 'likes', 'comments', 'shares', 'comment_id', 'comment_url',
#        'commenter_id', 'commenter_name', 'comment_text', 'comment_time',
#        'reply_id', 'reply_url', 'replier_id', 'replier_name', 'reply_text',
#        'reply_time'],
#       dtype='object')

# %% [markdown]
# The column post_text contains dreams. The column comment_text contains dream-interpretations. However, not all cases are actual dreams or dream-interpretations. Some comments may be admin-posts about group-guidelines. Some comments are additional addons by the poster, or just comments without interpretations. Some dream-posts are also very short, and some posts and comments are duplicates. We can use post_id, or comment_id to check for duplicates. <br>
# Let's remove all rows without comments.

# %%
dreams_raw.dropna(subset=['comment_id', 'comment_text','post_text', 'post_id'], inplace=True)

# %%
dreams_raw.shape
# Out:
# (1570, 22)

# %% [markdown]
# And remove duplicate comments. Duplicate comments indicate that comments were again comented on.

# %%
dreams = dreams_raw.drop_duplicates(subset='comment_id')

# %% [markdown]
# The first post is a welcome post describing the purpose of the group. It is pinned and has many comments. Those aren't dreams. So let's delete those rows too. We can use the post id.

# %%
dreams = dreams[dreams.post_id != dreams.loc[0,'post_id']]
print("shape dreams",dreams.shape)
dreams.head()
# Out:
# shape dreams (763, 22)
#             page_id           post_id  \
# 26  546590529195943  1418344718687182
# 29  546590529195943  1414798689041785
# 30  546590529195943  1414798689041785
# 31  546590529195943  1417898688731785
# 32  546590529195943  1417604302094557
#
#                                              post_url          user_id  \
# 26  https://m.facebook.com/groups/546590529195943/...  410066253948006
# 29  https://m.facebook.com/groups/546590529195943/...       1190885453
# 30  https://m.facebook.com/groups/546590529195943/...       1190885453
# 31  https://m.facebook.com/groups/546590529195943/...  100004875131908
# 32  https://m.facebook.com/groups/546590529195943/...        717670376
#
#                            user_name  \
# 26  Dream Symbols and Interpretation
# 29                Marie Glaze Shahan
# 30                Marie Glaze Shahan
# 31              Ashcharya Wickramage
# 32                      Rachel Parry
#
#                                             post_text            post_time  \
# 26  Hello I had this dream about my husband ex. In...  2022-05-08 14:26:53
# 29  Mother's day is coming up, it will be the firs...  2022-05-05 03:46:47
# 30  Mother's day is coming up, it will be the firs...  2022-05-05 03:46:47
# 31  Need some interpretation:\n\nI was walking on ...  2022-05-08 05:03:50
# 32  Good morning.\n\nI keep having a dream where i...  2022-05-07 21:39:19
#
#     likes  comments  shares  ...  commenter_id        commenter_name  \
# 26    0.0         1       0  ...  4.100663e+14          Group member
# 29    1.0         2       0  ...  5.603456e+08    Alexandra Moulding
# 30    1.0         2       0  ...  1.000640e+14  Georgia Maisie Jayne
# 31    0.0         1       0  ...  5.603456e+08    Alexandra Moulding
# 32    0.0         1       0  ...  5.603456e+08    Alexandra Moulding
#
#                                          comment_text         comment_time  \
# 26  The man that she was standing in the photo wit...  2022-05-08 14:37:36
# 29                             What a beautiful dream  2022-05-05 00:00:00
# 30  Oh that’s wonderful! I’ve had a very similar d...  2022-05-08 12:40:41
# 31  This is such a beautiful dream. I feel it refl...  2022-05-08 10:40:43
# 32  Hi, my suggestion is that the dream is about a...  2022-05-07 22:40:45
#
#         reply_id                              reply_url   replier_id  \
# 26           NaN                                    NaN          NaN
# 29           NaN                                    NaN          NaN
# 30           NaN                                    NaN          NaN
# 31           NaN                                    NaN          NaN
# 32  1.417618e+15  https://facebook.com/1417618045426516  717670376.0
#
#     replier_name                                         reply_text  \
# 26           NaN                                                NaN
# 29           NaN                                                NaN
# 30           NaN                                                NaN
# 31           NaN                                                NaN
# 32  Rachel Parry  Alexandra Moulding what kind of thing/part of ...
#
#              reply_time
# 26                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32  2022-05-07 22:40:45
#
# [5 rows x 22 columns]

# %% [markdown]
# Sometimes the original poster commented on his own dream. Let's remove all rows where user_id and commenter_id are identical

# %%
dreams = dreams[dreams['user_id']!= dreams['commenter_id']]
dreams.shape
# Out:
# (732, 22)

# %% [markdown]
# The next simplifications of the dataset are going to be a bit more arbitrary. We want to remove too short dream-texts and interpretations. To get a good overview we want to cluster by length. Doing that we are going to get a sense of the difference between quality dream-texts and interpretations and other short texts and comments. Especially in the comment section, quite a few comments are not actually interpretations, but other types of comments, like "nice dream".

# %%
import nltk

# %%
posts = pd.DataFrame(dreams['post_text'].drop_duplicates())
posts['length']=posts['post_text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
#import matplotlib.pyplot as plt
posts['length'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
posts['length'].describe()
# Out:
# count    361.000000
# mean     155.734072
# std      132.635010
# min       12.000000
# 25%       70.000000
# 50%      114.000000
# 75%      207.000000
# max      919.000000
# Name: length, dtype: float64

# %% [markdown]
# The length of dream texts varies between 12 tokens and 919 tokens. The mean of 156 is above the median of 114. Let's apply kmeans clustering.

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(init="random",n_clusters=2,n_init=10, max_iter=300)
kmeans.fit(np.expand_dims(np.array(posts['length']), axis=1))
# Out:
# KMeans(init='random', n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[350.2875    ],
#        [100.34519573]])

# %%
np.unique(kmeans.labels_, return_counts=True)
# Out:
# (array([0, 1], dtype=int32), array([ 80, 281]))

# %%
posts[kmeans.labels_==1]['length'].describe()
# Out:
# count    281.000000
# mean     100.345196
# std       53.203703
# min       12.000000
# 25%       60.000000
# 50%       93.000000
# 75%      136.000000
# max      224.000000
# Name: length, dtype: float64

# %%
posts[kmeans.labels_==0]['length'].describe()
# Out:
# count     80.000000
# mean     350.287500
# std      144.537166
# min      226.000000
# 25%      256.250000
# 50%      320.500000
# 75%      367.000000
# max      919.000000
# Name: length, dtype: float64

# %%
comments = pd.DataFrame(dreams['comment_text'].drop_duplicates())
comments['length']=0
for i in range(len(comments)):
    comments.iloc[i,1]= len(nltk.word_tokenize(comments.iloc[i,0]))

# %%
comments['length']=comments['comment_text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
#import matplotlib.pyplot as plt
comments['length'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
comments['length'].describe()
# Out:
# count    732.000000
# mean      66.631148
# std       77.725308
# min        1.000000
# 25%       22.000000
# 50%       44.000000
# 75%       83.250000
# max      706.000000
# Name: length, dtype: float64

# %% [markdown]
# The length of comment texts varies between 1 tokens and 706 tokens. The mean of 66 is above the median of 44. Let's apply kmeans clustering.

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(init="random",n_clusters=2,n_init=10, max_iter=300)
kmeans.fit(np.expand_dims(np.array(comments['length']), axis=1))
# Out:
# KMeans(init='random', n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[310.21428571],
#        [ 51.80434783]])

# %%
np.unique(kmeans.labels_, return_counts=True)
# Out:
# (array([0, 1], dtype=int32), array([ 42, 690]))

# %%
comments[kmeans.labels_==1]['length'].describe()
# Out:
# count    690.000000
# mean      51.804348
# std       40.145754
# min        1.000000
# 25%       21.000000
# 50%       41.000000
# 75%       73.750000
# max      177.000000
# Name: length, dtype: float64

# %%
comments[kmeans.labels_==0]['length'].describe()
# Out:
# count     42.000000
# mean     310.214286
# std      127.070661
# min      185.000000
# 25%      216.750000
# 50%      260.500000
# 75%      360.250000
# max      706.000000
# Name: length, dtype: float64

# %% [markdown]
# We have two clusters of comments by length. 310 comments fall in the cluster with min length of 1 and max length of 224, and the other 80 dreams have length between 226 and 919 tokens.

# %%
comments
# Out:
#                                            comment_text  length
# 29                               What a beautiful dream       4
# 30    Oh that’s wonderful! I’ve had a very similar d...      67
# 31    This is such a beautiful dream. I feel it refl...      86
# 32    Hi, my suggestion is that the dream is about a...      50
# 39    What a fabulous dream! Trust your instinct on ...      32
# ...                                                 ...     ...
# 1596  Who took the overdose? Earl or his identical b...      11
# 1597  The title I feel holds your answer. It's tied ...      16
# 1601  The money represents some gain or wealth that ...      54
# 1602  Maybe something related to "coming of age" or ...      40
# 1603  Perhaps it's anxiety about change..I new count...      25
#
# [732 rows x 2 columns]

# %% [markdown]
# The clustering was not helpfull. We decide to sort the posts and comments by length, to get a subjective impression of what length constitutes a good dream-txt and interpretation. We are going to use that as a cutoff. What is noticable is that the shorter dream posts are questions about particular dream-symbols like: "This is the second night I dreamt about elevators. What do elevators mean?". These questions about symbols are not so usefull and don't match our Jungian psychological theory about dreams. We are interested in narrative dream-texts. The meaning of elements is found in the relationship to the whole dream-narrative. We are going to filter out, so that we only have narrative dream-texts.

# %%
#import matplotlib.pyplot as plt
comments['length'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
comments['length'].describe()
# Out:
# count    732.000000
# mean      66.631148
# std       77.725308
# min        1.000000
# 25%       22.000000
# 50%       44.000000
# 75%       83.250000
# max      706.000000
# Name: length, dtype: float64

# %% [markdown]
# The length of comment texts varies between 1 tokens and 706 tokens. The mean of 66 is above the median of 44. Let's apply kmeans clustering.

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(init="random",n_clusters=2,n_init=10, max_iter=300)
kmeans.fit(np.expand_dims(np.array(comments['length']), axis=1))
# Out:
# KMeans(init='random', n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[310.21428571],
#        [ 51.80434783]])

# %%
np.unique(kmeans.labels_, return_counts=True)
# Out:
# (array([0, 1], dtype=int32), array([ 42, 690]))

# %%
comments[kmeans.labels_==1]['length'].describe()
# Out:
# count    690.000000
# mean      51.804348
# std       40.145754
# min        1.000000
# 25%       21.000000
# 50%       41.000000
# 75%       73.750000
# max      177.000000
# Name: length, dtype: float64

# %%
comments[kmeans.labels_==0]['length'].describe()
# Out:
# count     42.000000
# mean     310.214286
# std      127.070661
# min      185.000000
# 25%      216.750000
# 50%      260.500000
# 75%      360.250000
# max      706.000000
# Name: length, dtype: float64

# %% [markdown]
# We have two clusters of comments by length. 310 comments fall in the cluster with min length of 1 and max length of 224, and the other 80 dreams have length between 226 and 919 tokens.

# %%
comments
# Out:
#                                            comment_text  length
# 29                               What a beautiful dream       4
# 30    Oh that’s wonderful! I’ve had a very similar d...      67
# 31    This is such a beautiful dream. I feel it refl...      86
# 32    Hi, my suggestion is that the dream is about a...      50
# 39    What a fabulous dream! Trust your instinct on ...      32
# ...                                                 ...     ...
# 1596  Who took the overdose? Earl or his identical b...      11
# 1597  The title I feel holds your answer. It's tied ...      16
# 1601  The money represents some gain or wealth that ...      54
# 1602  Maybe something related to "coming of age" or ...      40
# 1603  Perhaps it's anxiety about change..I new count...      25
#
# [732 rows x 2 columns]

# %%
posts
# Out:
#                                               post_text  length
# 29    Mother's day is coming up, it will be the firs...      92
# 31    Need some interpretation:\n\nI was walking on ...     129
# 32    Good morning.\n\nI keep having a dream where i...      77
# 39    So I woke up from a very strange dream. I ofte...     319
# 41    So I had a dream the other night which really ...     110
# ...                                                 ...     ...
# 1591  I keep having these dreams about being in dang...      68
# 1592  Thank you for accepting my request this is goi...     355
# 1597  Does anyone know why we dream of a certain son...      73
# 1601  Hello, so this is so weird bc I had said to a ...      95
# 1602  Had a dream... was like the country was going ...     117
#
# [361 rows x 2 columns]

# %% [markdown]
# We are manually going to check the content of a few posts and find the minimal length of dreams being written in a narrative form. Then we are going to delte all shorter posts. Below is an example of an acceptable narrative dream-post. The text has quite a few errors in it though. It is quite short, with a token-length of 73. Let's look for instances of shorter posts that don't comply with the criterion of being narrative form.

# %%
posts.loc[259,'post_text']
# Out:
# 'I dreamed that I was joy riding on a bus downtown and lost control and hit one of the buildings down River St. Afterwards, me and other people on the bus were having a meeting was blaming the bus driver for taking too long to long and some were blaming me because others have other things to do and they were gonna be late. I woke up quick.'

# %% [markdown]
# Here is an example of a non-narrative dream-post. The poster is only asking about the meaning of a particular motive, without a narrative.

# %%
posts.loc[793,'post_text']
# Out:
# 'Hello all, I have recently dreamed of some fractal lights/rainbow reflected on water. It was very vivid and beautiful. Can someone please help interpreting? Tia x'

# %% [markdown]
# The shortest post we are going to include is token length of 45. This is the particular dream which seems to meet our minimal narrative criteria.

# %%
posts.loc[869,'post_text']
# Out:
# 'Hi guys I dreamed I was fishing …line got stuck and went down there was a shark and another attacking each other on the line and they kept coming I kept being pulled until I let go and went up what does it mean?'

# %% [markdown]
# Let's make the same decision for dream interpretations. These can be quite short. The criterion from the jungian theory of a valid dream interpretations is helpfulness and insightfulness. In principle a single sentence can fulfill these criteria. Of course we would love our model to create much more sophisticated interpretations. But most comments are a one-sentence interpretation. This interpretation below has 13 tokens.

# %%
comments.loc[1217,'comment_text']
# Out:
# 'you are resisting a change that it vital for your future growth.'

# %% [markdown]
# Let's create our dataset containing of posts with at least 45 tokens and comments with at least 13 tokens.

# %%
dreams['length_post']=dreams['post_text'].apply(lambda x: len(nltk.word_tokenize(x)))
dreams['length_comment']=dreams['comment_text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
np.corrcoef(dreams.length_post,dreams.length_comment)
# Out:
# array([[1.        , 0.24270779],
#        [0.24270779, 1.        ]])

# %%
dreams = dreams[(dreams['length_post']>= 45) & (dreams['length_comment']>=13)]
dreams.shape
# Out:
# (515, 24)

# %% [markdown]
# we have 515 comments left. Let's see how many posts are included

# %%
dreams['post_id'].nunique()
# Out:
# 312

# %% [markdown]
# there are 312 posts (or potential dreams). These are the numbers for minimal quality standards. Now we are going to maximize the quality standards. We are subjectively going to look at dream-texts and only decide to include lengths of those we unambivalentely consider high quality.

# %%
dreams.loc[1141,'post_text']
# Out:
# 'I had a dream that me and my fiancé were back in high school (neither of us knew each other in high school, went to the same school, or even lived in the same state). In my dream, we were in class and I had a major crush on him so I would look at him any chance I got. When I woke up I felt extremely in love with him, anyone know why this happens?'

# %% [markdown]
# This dream is the lowest quality standard for inclusion. It consists of 85 tokens. Let's check the interpretations (comments).

# %%
dreams.loc[966,'comment_text']
# Out:
# 'To me in this dream you are being challenged in life. That you are with your sil represents traits she has are about yourself. This is about you struggling to move forward in life.'

# %% [markdown]
# This comment has a length of 37 tokens. Let's see how many tuples we are left with when choosing posts with minimum length of 85 tokens and comments with length of 37 tokens.

# %%
dreams_high_qual = dreams[(dreams['length_post']>= 85) & (dreams['length_comment']>=37)]
dreams_high_qual.shape
# Out:
# (273, 24)

# %% [markdown]
# Now for both high and low quality we are going to manually go through each post and comment and see if they are actually dreams and dream-interpretations. Let's save the tables with the relevant columns.

# %%
columns_relevant = ['user_id', 'post_text', 'post_time', 'likes', 'comments', 'comment_id', 'commenter_id', 'comment_text', 'comment_time', 'length_post', 'length_comment']

# %%
dreams[columns_relevant].to_csv('Data/dream_symbols_and_interpretation_lowQ.csv')
dreams_high_qual[columns_relevant].to_csv('Data/dream_symbols_and_interpretation_highQ.csv')

# %% [markdown]
# To repeat all the steps above on other datasets with the same structure, a python file with a function is provided in the repository called dream_preprocessing.py

# %% [markdown]
# Let's import the manually cleaned lowQ-Dataset.

# %%
dreams_clean_lowQ = pd.read_csv("Data/dream_symbols_and_interpretation_lowQ_clean.csv", index_col=0)
dreams_clean_lowQ

# %% [markdown]
# To remove the deleted rows also from the high-quality dataset, we take the rows which exist in both datasets. We use the set-funtion on indeces.

# %%
dreams_clean_highQ =dreams_high_qual.loc[set(dreams_clean_lowQ.index) & set(dreams_high_qual.index)][list(dreams_clean_lowQ.columns)]
dreams_clean_highQ.to_csv("Data/dream_symbols_and_interpretation_highQ.csv")
# Out:
# /tmp/ipykernel_30673/4148793892.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   dreams_clean_highQ =dreams_high_qual.loc[set(dreams_clean_lowQ.index) & set(dreams_high_qual.index)][list(dreams_clean_lowQ.columns)]

# %%
print("size low quality",dreams_clean_lowQ.shape)
print("size high quality",dreams_clean_highQ.shape)
# Out:
# size low quality (332, 11)
# size high quality (223, 11)

# %% [markdown]
# Some more cleaning of the data was necessary. We created two new columns indicating provided background information by dreamers and reported wakeup states. Those were sometimes included in the dream-reports. Let's load the cleaned dataset.

# %%
dreams_symbols_clean = pd.read_csv("Data/dream_symbols_and_interpretation_highQ_clean.csv", index_col=0)
dreams_symbols_clean.shape
# Out:
# (188, 13)

# %% [markdown]
# The high quality data-frame is sufficiently large for our purposes. We have one more dataset from a different facebook group. Let's apply the dream_preprocess function we created before manually selecting the dreams and comments that show sufficient quality.

# %%
from dream_preprocessing import dream_preprocess
dreams_2= dream_preprocess('Data/FB_scraped_Jordan_Peterson.csv',85,37)
print(dreams_2.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25072/1342762079.py in <module>
#       1 from dream_preprocessing import dream_preprocess
# ----> 2 dreams_2= dream_preprocess('Data/FB_scraped_Jordan_Peterson.csv',85,37)
#       3 print(dreams_2.shape)
#
# ~\OneDrive\Desktop\GPT-3 Fine tuning\Pulled Repo\dreami\ai_model\dream_preprocessing.py in dream_preprocess(file, min_post, min_comment)
#       4
#       5 def dream_preprocess(file:str, min_post: int, min_comment:int)->pd.DataFrame:
# ----> 6     dreams_raw = pd.read_csv(file)
#       7     dreams_raw.dropna(subset=['comment_id', 'comment_text','post_text', 'post_id'], inplace=True)
#       8     dreams = dreams_raw.drop_duplicates(subset='comment_id')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/FB_scraped_Jordan_Peterson.csv'

# %%
dreams_2.to_csv('Data/dreams_Jordan_Peterson.csv')

# %%
dreams_JP_clean = pd.read_csv("Data/dreams_Jordan_Peterson_clean.csv", index_col=0)
dreams_JP_clean.shape
# Out:
# (129, 13)

# %%
data1= dreams_symbols_clean
data2= dreams_JP_clean

# %%
#Dropping irrelevant columns in data1

data1= data1.drop([ 'user_id', 'post_time', 'likes', 'comments', 'comment_id', 'commenter_id', 'comment_time', 'length_post', 'length_comment'], axis=1 )

data1
# Out:
#                                               post_text  \
# 1536  Dreamt my daughter, who is a mentally disabled...
# 1537  Dreamt my daughter, who is a mentally disabled...
# 1540  Dreamt my daughter, who is a mentally disabled...
# 1541  Dreamt my daughter, who is a mentally disabled...
# 1030  I was downstairs watching tv with my daughter ...
# ...                                                 ...
# 504   My brother in law had a girl added as his sist...
# 506   I was at my work, and had walked to my car. I ...
# 1530  Last night I dreamt that he was back, I was a ...
# 1531  There was a male individual that was ousted fr...
# 509   In the dream my guy friend sits on a bench nex...
#
#                                            comment_text  \
# 1536  What an empowering dream! I love it! Your daug...
# 1537  I think it can mean there is anxiety in you ab...
# 1540  The dream may be about your or her self contro...
# 1541  This is beautiful, reminds me of the strength ...
# 1030  If you were having a hot flush in your sleep, ...
# ...                                                 ...
# 504   I get the feeling this is s woman posting. My ...
# 506   It could be to do with your behavior in regard...
# 1530  To me I feel like your dreams are telling you ...
# 1531  This is about you evolving and taking a stand ...
# 509   The dream might indicate a time of waiting or ...
#
#                                         background_info  \
# 1536                                                NaN
# 1537                                                NaN
# 1540                                                NaN
# 1541                                                NaN
# 1030                                                NaN
# ...                                                 ...
# 504                                                 NaN
# 506                                                 NaN
# 1530   I have had so many sad dreams for about a yea...
# 1531                                                NaN
# 509                                                 NaN
#
#                                            wakeup_state
# 1536                                                NaN
# 1537                                                NaN
# 1540                                                NaN
# 1541  It felt scary but also good in a sense when I ...
# 1030  I very abruptly wake up from this dream and my...
# ...                                                 ...
# 504                                                 NaN
# 506                                                 NaN
# 1530   and then I woke up crying. It feels like the ...
# 1531            I woke up feeling very sad and guilty.
# 509                                                 NaN
#
# [188 rows x 4 columns]

# %%
#Dropping irrelevant columns in data2

data2= data2.drop(['user_id', 'post_time', 'likes', 'comments', 'comment_id', 'commenter_id', 'comment_time', 'length_post', 'length_comment'], axis=1 )

data2
# Out:
#                                               post_text  \
# 171   I was walking through medieval cellars that we...
# 172   I was walking through medieval cellars that we...
# 179   I was somehow involved in a murder. An acquain...
# 219   I am walking around a dilapidated city. It is ...
# 249   In my dream, I am in the attic of a palatial b...
# ...                                                 ...
# 3515  In the dream I was swimming in a pool at a bea...
# 3518  In the dream I was swimming in a pool at a bea...
# 3526  In the dream I was swimming in a pool at a bea...
# 3557  I am together with a middle aged woman, an old...
# 3559  I was 17-18 so about 15-16 years ago. One of m...
#
#                                            comment_text  \
# 171   The dark, ominous "shadow" chasing you was you...
# 172   This is one of those dreams that sound amazing...
# 179   Jung spoke about how the 'strong man', or thug...
# 219   There's a lot of layers in this dream. I'll ju...
# 249   Are other coffins empty? Must be if you said o...
# ...                                                 ...
# 3515  The message I would take pivots on the makeup....
# 3518  If we look at a dream as your subconscious try...
# 3526  Yes it sounds to me like all appearance - the ...
# 3557  Oh cool - waking up to self deception from you...
# 3559  It sounds something like you had great peace a...
#
#                                         background_info  \
# 171                                                 NaN
# 172                                                 NaN
# 179                                                 NaN
# 219                                                 NaN
# 249                                                 NaN
# ...                                                 ...
# 3515  Obsessing over the girl in my dream. She is a ...
# 3518  Obsessing over the girl in my dream. She is a ...
# 3526  Obsessing over the girl in my dream. She is a ...
# 3557  I wake up thinking that while the culture and ...
# 3559                                                NaN
#
#                                            wakeup_state
# 171                          I woke up cold and anxious
# 172                          I woke up cold and anxious
# 179   This was one of those ones you wake up shaking...
# 219                                                 NaN
# 249                                                 NaN
# ...                                                 ...
# 3515                                                NaN
# 3518                                                NaN
# 3526                                                NaN
# 3557                                                NaN
# 3559                                                NaN
#
# [129 rows x 4 columns]

# %%
#Merging the 2 datasets as one

data3 = data1.merge(data2, on= ['post_text', 'comment_text', 'background_info', 'wakeup_state'], how = 'outer')

data3
# Out:
#                                              post_text  \
# 0    Dreamt my daughter, who is a mentally disabled...
# 1    Dreamt my daughter, who is a mentally disabled...
# 2    Dreamt my daughter, who is a mentally disabled...
# 3    Dreamt my daughter, who is a mentally disabled...
# 4    I was downstairs watching tv with my daughter ...
# ..                                                 ...
# 312  In the dream I was swimming in a pool at a bea...
# 313  In the dream I was swimming in a pool at a bea...
# 314  In the dream I was swimming in a pool at a bea...
# 315  I am together with a middle aged woman, an old...
# 316  I was 17-18 so about 15-16 years ago. One of m...
#
#                                           comment_text  \
# 0    What an empowering dream! I love it! Your daug...
# 1    I think it can mean there is anxiety in you ab...
# 2    The dream may be about your or her self contro...
# 3    This is beautiful, reminds me of the strength ...
# 4    If you were having a hot flush in your sleep, ...
# ..                                                 ...
# 312  The message I would take pivots on the makeup....
# 313  If we look at a dream as your subconscious try...
# 314  Yes it sounds to me like all appearance - the ...
# 315  Oh cool - waking up to self deception from you...
# 316  It sounds something like you had great peace a...
#
#                                        background_info  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 312  Obsessing over the girl in my dream. She is a ...
# 313  Obsessing over the girl in my dream. She is a ...
# 314  Obsessing over the girl in my dream. She is a ...
# 315  I wake up thinking that while the culture and ...
# 316                                                NaN
#
#                                           wakeup_state
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    It felt scary but also good in a sense when I ...
# 4    I very abruptly wake up from this dream and my...
# ..                                                 ...
# 312                                                NaN
# 313                                                NaN
# 314                                                NaN
# 315                                                NaN
# 316                                                NaN
#
# [317 rows x 4 columns]

# %%
#Filling the missing values as ' __ '
data3.fillna('__', inplace=True)
data3
# Out:
#                                              post_text  \
# 0    Dreamt my daughter, who is a mentally disabled...
# 1    Dreamt my daughter, who is a mentally disabled...
# 2    Dreamt my daughter, who is a mentally disabled...
# 3    Dreamt my daughter, who is a mentally disabled...
# 4    I was downstairs watching tv with my daughter ...
# ..                                                 ...
# 312  In the dream I was swimming in a pool at a bea...
# 313  In the dream I was swimming in a pool at a bea...
# 314  In the dream I was swimming in a pool at a bea...
# 315  I am together with a middle aged woman, an old...
# 316  I was 17-18 so about 15-16 years ago. One of m...
#
#                                           comment_text  \
# 0    What an empowering dream! I love it! Your daug...
# 1    I think it can mean there is anxiety in you ab...
# 2    The dream may be about your or her self contro...
# 3    This is beautiful, reminds me of the strength ...
# 4    If you were having a hot flush in your sleep, ...
# ..                                                 ...
# 312  The message I would take pivots on the makeup....
# 313  If we look at a dream as your subconscious try...
# 314  Yes it sounds to me like all appearance - the ...
# 315  Oh cool - waking up to self deception from you...
# 316  It sounds something like you had great peace a...
#
#                                        background_info  \
# 0                                                   __
# 1                                                   __
# 2                                                   __
# 3                                                   __
# 4                                                   __
# ..                                                 ...
# 312  Obsessing over the girl in my dream. She is a ...
# 313  Obsessing over the girl in my dream. She is a ...
# 314  Obsessing over the girl in my dream. She is a ...
# 315  I wake up thinking that while the culture and ...
# 316                                                 __
#
#                                           wakeup_state
# 0                                                   __
# 1                                                   __
# 2                                                   __
# 3    It felt scary but also good in a sense when I ...
# 4    I very abruptly wake up from this dream and my...
# ..                                                 ...
# 312                                                 __
# 313                                                 __
# 314                                                 __
# 315                                                 __
# 316                                                 __
#
# [317 rows x 4 columns]

# %%
#Randomizing the rows of the dataset

data3= data3.sample(frac=1).reset_index(drop=True)
data3
# Out:
#                                              post_text  \
# 0    I was house sitting for a family member. I wal...
# 1    I'm driving a car in a world I am familiar wit...
# 2    I was in a huge house with a bunch of friends,...
# 3    In my dream I saw a blonde girl. She was cute;...
# 4    I visit the town and I walk along the street w...
# ..                                                 ...
# 312  I was at some kind of archeological dig. The m...
# 313  Part one: I enter a large stone building that ...
# 314  I was in a hospital. A female colleague of min...
# 315  I had a dream that I bought a car from my sist...
# 316  It started in the middle for me, I was in my r...
#
#                                           comment_text  \
# 0    It could be about dealing with a problem that ...
# 1    Hmm - with it being a battle with Aragorn vs y...
# 2    The spiral staircases is a reasonably common m...
# 3    The Blonde girl is a magician illusionist, sor...
# 4    My first thought is that your dream could be l...
# ..                                                 ...
# 312  I guess you don't make the decision because yo...
# 313  I think that the first part means that you are...
# 314  Well, what does a nurse mean to you? The colle...
# 315  I see the car as a journey, might be about how...
# 316  This is a pretty complex dream, I’m not sure I...
#
#                                        background_info  \
# 0                                                   __
# 1    Most times when I have a nightmare I am runnin...
# 2    Overall I only have wild, violent dreams and s...
# 3                                                   __
# 4    I’ve had this dream before. It probably isn’t ...
# ..                                                 ...
# 312  I've recently been in contact with an ex-girlf...
# 313  My stresses are through the roof these days. I...
# 314                                                 __
# 315  I worked at Fed Ex in the past. Thankfully I h...
# 316                                                 __
#
#                                           wakeup_state
# 0    It was all so surreal I laughed a little when ...
# 1                                                   __
# 2                                                   __
# 3                                                   __
# 4                                                   __
# ..                                                 ...
# 312                                                 __
# 313                                                 __
# 314                                                 __
# 315                                                 __
# 316                                                 __
#
# [317 rows x 4 columns]

# %%
#Adding relevant separators

data3["sep2"]= [' ; '] * len(data3)
data3['sepback'] = [' Background_Info: '] * len(data3)
data3['sepdream'] = ['Dream_Text: '] * len(data3)
data3['sepwake'] = [' Wakeup_State: '] * len(data3)

data3
# Out:
#                                              post_text  \
# 0    I was house sitting for a family member. I wal...
# 1    I'm driving a car in a world I am familiar wit...
# 2    I was in a huge house with a bunch of friends,...
# 3    In my dream I saw a blonde girl. She was cute;...
# 4    I visit the town and I walk along the street w...
# ..                                                 ...
# 312  I was at some kind of archeological dig. The m...
# 313  Part one: I enter a large stone building that ...
# 314  I was in a hospital. A female colleague of min...
# 315  I had a dream that I bought a car from my sist...
# 316  It started in the middle for me, I was in my r...
#
#                                           comment_text  \
# 0    It could be about dealing with a problem that ...
# 1    Hmm - with it being a battle with Aragorn vs y...
# 2    The spiral staircases is a reasonably common m...
# 3    The Blonde girl is a magician illusionist, sor...
# 4    My first thought is that your dream could be l...
# ..                                                 ...
# 312  I guess you don't make the decision because yo...
# 313  I think that the first part means that you are...
# 314  Well, what does a nurse mean to you? The colle...
# 315  I see the car as a journey, might be about how...
# 316  This is a pretty complex dream, I’m not sure I...
#
#                                        background_info  \
# 0                                                   __
# 1    Most times when I have a nightmare I am runnin...
# 2    Overall I only have wild, violent dreams and s...
# 3                                                   __
# 4    I’ve had this dream before. It probably isn’t ...
# ..                                                 ...
# 312  I've recently been in contact with an ex-girlf...
# 313  My stresses are through the roof these days. I...
# 314                                                 __
# 315  I worked at Fed Ex in the past. Thankfully I h...
# 316                                                 __
#
#                                           wakeup_state sep2  \
# 0    It was all so surreal I laughed a little when ...   ;
# 1                                                   __   ;
# 2                                                   __   ;
# 3                                                   __   ;
# 4                                                   __   ;
# ..                                                 ...  ...
# 312                                                 __   ;
# 313                                                 __   ;
# 314                                                 __   ;
# 315                                                 __   ;
# 316                                                 __   ;
#
#                 sepback      sepdream          sepwake
# 0     Background_Info:   Dream_Text:    Wakeup_State:
# 1     Background_Info:   Dream_Text:    Wakeup_State:
# 2     Background_Info:   Dream_Text:    Wakeup_State:
# 3     Background_Info:   Dream_Text:    Wakeup_State:
# 4     Background_Info:   Dream_Text:    Wakeup_State:
# ..                  ...           ...              ...
# 312   Background_Info:   Dream_Text:    Wakeup_State:
# 313   Background_Info:   Dream_Text:    Wakeup_State:
# 314   Background_Info:   Dream_Text:    Wakeup_State:
# 315   Background_Info:   Dream_Text:    Wakeup_State:
# 316   Background_Info:   Dream_Text:    Wakeup_State:
#
# [317 rows x 8 columns]

# %%
#Adding the input column

data3['input'] = data3['sepdream'] + data3["post_text"]+ data3['sep2'] + data3['sepback'] + data3["background_info"] +data3['sep2']+ data3['sepwake'] + data3['wakeup_state']

data3
# Out:
#                                              post_text  \
# 0    I was house sitting for a family member. I wal...
# 1    I'm driving a car in a world I am familiar wit...
# 2    I was in a huge house with a bunch of friends,...
# 3    In my dream I saw a blonde girl. She was cute;...
# 4    I visit the town and I walk along the street w...
# ..                                                 ...
# 312  I was at some kind of archeological dig. The m...
# 313  Part one: I enter a large stone building that ...
# 314  I was in a hospital. A female colleague of min...
# 315  I had a dream that I bought a car from my sist...
# 316  It started in the middle for me, I was in my r...
#
#                                           comment_text  \
# 0    It could be about dealing with a problem that ...
# 1    Hmm - with it being a battle with Aragorn vs y...
# 2    The spiral staircases is a reasonably common m...
# 3    The Blonde girl is a magician illusionist, sor...
# 4    My first thought is that your dream could be l...
# ..                                                 ...
# 312  I guess you don't make the decision because yo...
# 313  I think that the first part means that you are...
# 314  Well, what does a nurse mean to you? The colle...
# 315  I see the car as a journey, might be about how...
# 316  This is a pretty complex dream, I’m not sure I...
#
#                                        background_info  \
# 0                                                   __
# 1    Most times when I have a nightmare I am runnin...
# 2    Overall I only have wild, violent dreams and s...
# 3                                                   __
# 4    I’ve had this dream before. It probably isn’t ...
# ..                                                 ...
# 312  I've recently been in contact with an ex-girlf...
# 313  My stresses are through the roof these days. I...
# 314                                                 __
# 315  I worked at Fed Ex in the past. Thankfully I h...
# 316                                                 __
#
#                                           wakeup_state sep2  \
# 0    It was all so surreal I laughed a little when ...   ;
# 1                                                   __   ;
# 2                                                   __   ;
# 3                                                   __   ;
# 4                                                   __   ;
# ..                                                 ...  ...
# 312                                                 __   ;
# 313                                                 __   ;
# 314                                                 __   ;
# 315                                                 __   ;
# 316                                                 __   ;
#
#                 sepback      sepdream          sepwake  \
# 0     Background_Info:   Dream_Text:    Wakeup_State:
# 1     Background_Info:   Dream_Text:    Wakeup_State:
# 2     Background_Info:   Dream_Text:    Wakeup_State:
# 3     Background_Info:   Dream_Text:    Wakeup_State:
# 4     Background_Info:   Dream_Text:    Wakeup_State:
# ..                  ...           ...              ...
# 312   Background_Info:   Dream_Text:    Wakeup_State:
# 313   Background_Info:   Dream_Text:    Wakeup_State:
# 314   Background_Info:   Dream_Text:    Wakeup_State:
# 315   Background_Info:   Dream_Text:    Wakeup_State:
# 316   Background_Info:   Dream_Text:    Wakeup_State:
#
#                                                  input
# 0    Dream_Text: I was house sitting for a family m...
# 1    Dream_Text: I'm driving a car in a world I am ...
# 2    Dream_Text: I was in a huge house with a bunch...
# 3    Dream_Text: In my dream I saw a blonde girl. S...
# 4    Dream_Text: I visit the town and I walk along ...
# ..                                                 ...
# 312  Dream_Text: I was at some kind of archeologica...
# 313  Dream_Text: Part one: I enter a large stone bu...
# 314  Dream_Text: I was in a hospital. A female coll...
# 315  Dream_Text: I had a dream that I bought a car ...
# 316  Dream_Text: It started in the middle for me, I...
#
# [317 rows x 9 columns]

# %%
#Dropping irrelevant columns

data3= data3.drop(['post_text', 'background_info', 'wakeup_state', 'sep2', 'sepback', 'sepdream', 'sepwake'], axis=1 )
data3 = data3.rename(columns={'comment_text': 'interpretation'})
data3
# Out:
#                                         interpretation  \
# 0    It could be about dealing with a problem that ...
# 1    Hmm - with it being a battle with Aragorn vs y...
# 2    The spiral staircases is a reasonably common m...
# 3    The Blonde girl is a magician illusionist, sor...
# 4    My first thought is that your dream could be l...
# ..                                                 ...
# 312  I guess you don't make the decision because yo...
# 313  I think that the first part means that you are...
# 314  Well, what does a nurse mean to you? The colle...
# 315  I see the car as a journey, might be about how...
# 316  This is a pretty complex dream, I’m not sure I...
#
#                                                  input
# 0    Dream_Text: I was house sitting for a family m...
# 1    Dream_Text: I'm driving a car in a world I am ...
# 2    Dream_Text: I was in a huge house with a bunch...
# 3    Dream_Text: In my dream I saw a blonde girl. S...
# 4    Dream_Text: I visit the town and I walk along ...
# ..                                                 ...
# 312  Dream_Text: I was at some kind of archeologica...
# 313  Dream_Text: Part one: I enter a large stone bu...
# 314  Dream_Text: I was in a hospital. A female coll...
# 315  Dream_Text: I had a dream that I bought a car ...
# 316  Dream_Text: It started in the middle for me, I...
#
# [317 rows x 2 columns]

# %%
data3['input'][2]  # A single input
# Out:
# 'Dream_Text: I was in a huge house with a bunch of friends, some of whom I recognized. It was pretty obvious that we were there to party and it seemed like a cabin in the woods. At one point, we talk about going onto the roof and the staircase is a spiral going up at least 10 floors on the outside. One of the women seems to speed up it like sonic the hedgehog in front of me. On the roof, it’s obvious we are in a mountain town and it’s lit with string lights and super pretty. An old man comes up from what seems to be a ladder on the side of the building on the other side from us and he motions to us saying something like, hey is this yours? He seems like a grounds keeper or building manager. We walk over and there’s a few benches with towels and unwrapped (but really neatly laid) condoms on them. I said something like “no, that must have been the people here before us?” And I had this grossed out feeling. He acts a bit funny about it, seems to be mad at us and then leaves. We keep talking and then he appears again right in front of us coming over onto the roof but this time he seems like he’s turned into an alien with a squid-like face. One of the guy leans down towards him and all of a sudden I become the alien and I shoot my tentacles at his mouth, punch a hole I. The back of his head and rip his mouth off to where there’s just a gaping black hole where it used to be but no blood. ;  Background_Info: Overall I only have wild, violent dreams and stopped dreaming for years until I read Alchemy: an introduction to the symbolism and psychology. I often feel I’m half awake and just following the journey and don’t wake up anxious or stressed, usually just super weirded out. ;  Wakeup_State: __'

# %%
#Converting the dataframe to jsonl and adding stop sequences

import json

def dump_jsonl(df, output_path, append= False):
    """
    Write list of objects to a JSON lines file.
    """
    mode = 'a+' if append else 'w'
    with open(output_path, mode, encoding='utf-8') as f:
        for i in range(len(df)):
            line={'prompt':df.iloc[i,1]+' ###', 'completion': ' ' + df.iloc[i,0]+' [END]'}
            json_record = json.dumps(line, ensure_ascii=False,separators=(',',':'))
            f.write(json_record + '\n')
    print('Wrote {} records to {}'.format(len(df), output_path))

dump_jsonl(data3, 'Data/newdata3.jsonl')
# Out:
# Wrote 317 records to Data/newdata3.jsonl
